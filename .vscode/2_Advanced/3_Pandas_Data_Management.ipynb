# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset 
import matplotlib.pyplot as plt

# Loading Data 
dataset = load_dataset("lukebarousse/data_jobs")
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
# Displaying a random sample of 10 rows from the DataFrame
df.sample(10)
# Out:
#               job_title_short  \
# 476113          Data Engineer
# 113404         Data Scientist
# 429259      Software Engineer
# 683982         Data Scientist
# 95273          Data Scientist
# 719721          Data Engineer
# 460858           Data Analyst
# 245841          Data Engineer
# 3165    Senior Data Scientist
# 726349           Data Analyst
#
#                                                 job_title  \
# 476113                               Cloud Data Engineers
# 113404                       Data Scientist - Urgent Role
# 429259                               Integration Engineer
# 683982                             Data Scientist (m/w/d)
# 95273                                       Model Analyst
# 719721                                  Big Data Engineer
# 460858                                       Data Analyst
# 245841                                      Data Engineer
# 3165               Senior Data Scientist, Medical Imaging
# ...

# %%
dataset = load_dataset("lukebarousse/data_jobs")
df_original = dataset['train'].to_pandas()

# %%
# making a copy of the original DataFrame to preserve the original data. You can perform data cleaning and manipulation on this copy without affecting the original DataFrame.
df_altered = df_original.copy()
